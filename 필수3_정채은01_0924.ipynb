# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#필수과제-3-（필수과제-３만-10/8일까지-과제-제출）" data-toc-modified-id="필수과제-3-（필수과제-３만-10/8일까지-과제-제출）-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>필수과제 3 （필수과제 ３만 10/8일까지 과제 제출）</a></span></li><li><span><a href="#데이터-전처리-(결측치)" data-toc-modified-id="데이터-전처리-(결측치)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>데이터 전처리 (결측치)</a></span><ul class="toc-item"><li><span><a href="#True가-False에-비해-압도적으로-적음" data-toc-modified-id="True가-False에-비해-압도적으로-적음-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>True가 False에 비해 압도적으로 적음</a></span></li><li><span><a href="#결측치-확인" data-toc-modified-id="결측치-확인-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>결측치 확인</a></span></li><li><span><a href="#결측치가-있는-데이터들의-정답값-분포-확인" data-toc-modified-id="결측치가-있는-데이터들의-정답값-분포-확인-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>결측치가 있는 데이터들의 정답값 분포 확인</a></span><ul class="toc-item"><li><span><a href="#(y값은-총-88373개)" data-toc-modified-id="(y값은-총-88373개)-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>(y값은 총 88373개)</a></span></li></ul></li><li><span><a href="#ArrDelayMinutes,-AirTime,-ActualElapsedTime,-TaxiIn,-ArrDelay,-ArrDel15,-ArrivalDelayGroups-컬럼" data-toc-modified-id="ArrDelayMinutes,-AirTime,-ActualElapsedTime,-TaxiIn,-ArrDelay,-ArrDel15,-ArrivalDelayGroups-컬럼-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>ArrDelayMinutes, AirTime, ActualElapsedTime, TaxiIn, ArrDelay, ArrDel15, ArrivalDelayGroups 컬럼</a></span><ul class="toc-item"><li><span><a href="#위-컬럼들은-결측치를-보유한-행만-정답값이-1임.-즉,-결측치가-아니면서-정답값이-1인-분포가-없음-->-결측치를-채울-수가-없다.-따라서-컬럼-삭제" data-toc-modified-id="위-컬럼들은-결측치를-보유한-행만-정답값이-1임.-즉,-결측치가-아니면서-정답값이-1인-분포가-없음-->-결측치를-채울-수가-없다.-따라서-컬럼-삭제-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>위 컬럼들은 결측치를 보유한 행만 정답값이 1임. 즉, 결측치가 아니면서 정답값이 1인 분포가 없음 -&gt; 결측치를 채울 수가 없다. 따라서 컬럼 삭제</a></span></li></ul></li><li><span><a href="#'DepTime'-,-'DepDelayMinutes',-'DepDelay'-,-'ArrTime'-,-'DepDel15'-,-'DepartureDelayGroups'-,-TaxiOut-,-'WheelsOff'-,-'-WheelsOn'-,-컬럼" data-toc-modified-id="'DepTime'-,-'DepDelayMinutes',-'DepDelay'-,-'ArrTime'-,-'DepDel15'-,-'DepartureDelayGroups'-,-TaxiOut-,-'WheelsOff'-,-'-WheelsOn'-,-컬럼-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>'DepTime' , 'DepDelayMinutes', 'DepDelay' , 'ArrTime' , 'DepDel15' , 'DepartureDelayGroups' , TaxiOut , 'WheelsOff' , ' WheelsOn' , 컬럼</a></span><ul class="toc-item"><li><span><a href="#이-컬럼들-역시-결측치-대부분이-정답값에-분포함.-결측치를-통계적으로-의미있게-채워넣기-힘듦,-오히려--정확도를-해칠-수도" data-toc-modified-id="이-컬럼들-역시-결측치-대부분이-정답값에-분포함.-결측치를-통계적으로-의미있게-채워넣기-힘듦,-오히려--정확도를-해칠-수도-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>이 컬럼들 역시 결측치 대부분이 정답값에 분포함. 결측치를 통계적으로 의미있게 채워넣기 힘듦, 오히려  정확도를 해칠 수도</a></span></li></ul></li><li><span><a href="#나머지-결측치" data-toc-modified-id="나머지-결측치-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>나머지 결측치</a></span></li><li><span><a href="#'Tail_Number'-컬럼도-레벨이-너무-다양하고-결측치의-정답값의-비율이-너무-높아-삭제" data-toc-modified-id="'Tail_Number'-컬럼도-레벨이-너무-다양하고-결측치의-정답값의-비율이-너무-높아-삭제-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>'Tail_Number' 컬럼도 레벨이 너무 다양하고 결측치의 정답값의 비율이 너무 높아 삭제</a></span></li><li><span><a href="#나머지-두-컬럼의-결측치는-개수가-너무-적어-데이터를-날림" data-toc-modified-id="나머지-두-컬럼의-결측치는-개수가-너무-적어-데이터를-날림-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>나머지 두 컬럼의 결측치는 개수가 너무 적어 데이터를 날림</a></span></li></ul></li><li><span><a href="#데이터-전처리(인코딩-및-컬럼-간소화)" data-toc-modified-id="데이터-전처리(인코딩-및-컬럼-간소화)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>데이터 전처리(인코딩 및 컬럼 간소화)</a></span><ul class="toc-item"><li><span><a href="#컬럼-설명서를-봤을-때,-비슷한-내용을-가진-컬럼도-있었고,-이미-인코딩-된-것-같은-컬럼도-있었음" data-toc-modified-id="컬럼-설명서를-봤을-때,-비슷한-내용을-가진-컬럼도-있었고,-이미-인코딩-된-것-같은-컬럼도-있었음-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>컬럼 설명서를 봤을 때, 비슷한 내용을 가진 컬럼도 있었고, 이미 인코딩 된 것 같은 컬럼도 있었음</a></span><ul class="toc-item"><li><span><a href="#날짜를-나타내는-컬럼들" data-toc-modified-id="날짜를-나타내는-컬럼들-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>날짜를 나타내는 컬럼들</a></span></li><li><span><a href="#나머지-컬럼들과-정답-레이블-간의-상관관계-파악" data-toc-modified-id="나머지-컬럼들과-정답-레이블-간의-상관관계-파악-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>나머지 컬럼들과 정답 레이블 간의 상관관계 파악</a></span></li><li><span><a href="#상관계수가-제일-높은-Quarter만-채택" data-toc-modified-id="상관계수가-제일-높은-Quarter만-채택-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>상관계수가 제일 높은 Quarter만 채택</a></span></li></ul></li><li><span><a href="#Origin-관련-컬럼들" data-toc-modified-id="Origin-관련-컬럼들-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Origin 관련 컬럼들</a></span><ul class="toc-item"><li><span><a href="#Origin-->-OriginAirportID-인코딩-됨" data-toc-modified-id="Origin-->-OriginAirportID-인코딩-됨-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Origin -&gt; OriginAirportID 인코딩 됨</a></span></li><li><span><a href="#OriginState,-OriginStateFips,-OriginStateName-->-OriginWac-인코딩-됨" data-toc-modified-id="OriginState,-OriginStateFips,-OriginStateName-->-OriginWac-인코딩-됨-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>OriginState, OriginStateFips, OriginStateName -&gt; OriginWac 인코딩 됨</a></span></li><li><span><a href="#OriginCityName-->-OriginWac-안에-범주-간소화-되어-인코딩-됨" data-toc-modified-id="OriginCityName-->-OriginWac-안에-범주-간소화-되어-인코딩-됨-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>OriginCityName -&gt; OriginWac 안에 범주 간소화 되어 인코딩 됨</a></span></li><li><span><a href="#상관계수-제일-높은-OriginWac만-채택" data-toc-modified-id="상관계수-제일-높은-OriginWac만-채택-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>상관계수 제일 높은 OriginWac만 채택</a></span></li></ul></li><li><span><a href="#destination-관련-컬럼들" data-toc-modified-id="destination-관련-컬럼들-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>destination 관련 컬럼들</a></span><ul class="toc-item"><li><span><a href="#Dest-->-DestAirportID-인코딩-됨" data-toc-modified-id="Dest-->-DestAirportID-인코딩-됨-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Dest -&gt; DestAirportID 인코딩 됨</a></span></li><li><span><a href="#DestState,-DestStateFips,-DestStateName-->-DestWac-인코딩-됨" data-toc-modified-id="DestState,-DestStateFips,-DestStateName-->-DestWac-인코딩-됨-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>DestState, DestStateFips, DestStateName -&gt; DestWac 인코딩 됨</a></span></li><li><span><a href="#DestCityName-->-OriginWac-안에-범주-간소화-되어-인코딩-됨" data-toc-modified-id="DestCityName-->-OriginWac-안에-범주-간소화-되어-인코딩-됨-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>DestCityName -&gt; OriginWac 안에 범주 간소화 되어 인코딩 됨</a></span></li><li><span><a href="#상관계수-제일-높은-DestWac만-채택" data-toc-modified-id="상관계수-제일-높은-DestWac만-채택-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>상관계수 제일 높은 DestWac만 채택</a></span></li></ul></li><li><span><a href="#문자형-컬럼-인코딩" data-toc-modified-id="문자형-컬럼-인코딩-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>문자형 컬럼 인코딩</a></span><ul class="toc-item"><li><span><a href="#문자형-데이터만-추출" data-toc-modified-id="문자형-데이터만-추출-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>문자형 데이터만 추출</a></span></li><li><span><a href="#Operating_Airline-컬럼,-IATA_Code_Operating_Airline-,-Airline컬럼은-같은-컬럼" data-toc-modified-id="Operating_Airline-컬럼,-IATA_Code_Operating_Airline-,-Airline컬럼은-같은-컬럼-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Operating_Airline 컬럼, IATA_Code_Operating_Airline , Airline컬럼은 같은 컬럼</a></span></li><li><span><a href="#IATA_Code_Marketing_Airline,-Marketing_Airline_Network-컬럼도-같은-컬럼" data-toc-modified-id="IATA_Code_Marketing_Airline,-Marketing_Airline_Network-컬럼도-같은-컬럼-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>IATA_Code_Marketing_Airline, Marketing_Airline_Network 컬럼도 같은 컬럼</a></span></li><li><span><a href="#인코딩" data-toc-modified-id="인코딩-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>인코딩</a></span></li></ul></li><li><span><a href="#인코딩-끝,-마지막으로-나머지-컬럼들-중-중복되는-컬럼이-없는지-확인" data-toc-modified-id="인코딩-끝,-마지막으로-나머지-컬럼들-중-중복되는-컬럼이-없는지-확인-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>인코딩 끝, 마지막으로 나머지 컬럼들 중 중복되는 컬럼이 없는지 확인</a></span></li></ul></li><li><span><a href="#중복없음,-인코딩-끝!" data-toc-modified-id="중복없음,-인코딩-끝!-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>중복없음, 인코딩 끝!</a></span></li><li><span><a href="#scaling" data-toc-modified-id="scaling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>scaling</a></span></li></ul></div>

# %% [markdown]
# # 필수과제 3 （필수과제 ３만 10/8일까지 과제 제출）
#
# 과제 데이터는 샘플데이터를 공유할 예정
# 해당 데이터를 가지고 전처리 후에 평가지표와 다른 모델들간의 비교 필요.
#
# 필수적으로 공유해야 하는 내용
# 데이터 전처리 방법 정리와 시각화
# (실제 데이터를 전처리 하는 과정에서 피처를 선택했던 이유나 전처리를 선택한 이유들을 정리해서 공유)
# 평가지표에 대한 임계값을 조절하면서 변화를 정리하자. (모델은 로지스틱으로 진행)
# 로지스틱에 있는 위의 임계값을 조절해서 실제 매트릭스가 어떤 식으로 변하는지를 정리
# 정확도, 정밀도, 재현율, ROC, AUC 까지 시각화를 통해 어떤 식으로 변화하는지 정리 필수
# 모델간의 비교 진행하기
# 로지스틱, DT, RF, KNN 3개의 모델을 가지고 직접 모델링을 진행하고
# 평가지표에 대한 비교 정리와 ROC 커브에 대한 시각화를 통해 어떤 모델을 선정할지 기준점 잡기

# %% [markdown]
# # 데이터 전처리 (결측치)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Combined_Flights_2018.csv')

# %%
df
# Out:
#          FlightDate                      Airline Origin Dest  Cancelled  \
# 0        2018-01-23            Endeavor Air Inc.    ABY  ATL      False
# 1        2018-01-24            Endeavor Air Inc.    ABY  ATL      False
# 2        2018-01-25            Endeavor Air Inc.    ABY  ATL      False
# 3        2018-01-26            Endeavor Air Inc.    ABY  ATL      False
# 4        2018-01-27            Endeavor Air Inc.    ABY  ATL      False
# ...             ...                          ...    ...  ...        ...
# 5689507  2018-09-11  Air Wisconsin Airlines Corp    SCE  IAD      False
# 5689508  2018-09-11  Air Wisconsin Airlines Corp    IAD  GSO      False
# 5689509  2018-09-11  Air Wisconsin Airlines Corp    EVV  ORD      False
# 5689510  2018-09-11  Air Wisconsin Airlines Corp    ORD  HPN      False
# 5689511  2018-09-11  Air Wisconsin Airlines Corp    HPN  ORD      False
#
#          Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# ...

# %%
df['Cancelled'].value_counts()
# Out:
# False    5601139
# True       88373
# Name: Cancelled, dtype: int64

# %% [markdown]
# ## True가 False에 비해 압도적으로 적음

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %% [markdown]
# ## 결측치 확인

# %%
np.where(df.isna().sum() != 0)
# Out:
# (array([ 7,  8,  9, 10, 11, 12, 13, 14, 29, 47, 48, 50, 51, 52, 53, 55, 56,
#         57, 60], dtype=int64),)

# %%
df_na = df.iloc[:,[ 7,  8,  9, 10, 11, 12, 13, 14, 29, 47, 48, 50, 51, 52, 53, 55, 56,
        57, 60]]

# %%
df_na.isna().sum()
# Out:
# DepTime                  85380
# DepDelayMinutes          86575
# DepDelay                 86575
# ArrTime                  90615
# ArrDelayMinutes         102893
# AirTime                 109271
# CRSElapsedTime               6
# ActualElapsedTime       102347
# Tail_Number              20548
# DepDel15                 86575
# DepartureDelayGroups     86575
# TaxiOut                  94694
# WheelsOff                94684
# WheelsOn                 97549
# TaxiIn                   97559
# ArrDelay                102893
# ArrDel15                102893
# ArrivalDelayGroups      102893
# DivAirportLandings           1
# dtype: int64

# %%
df_na.columns
# Out:
# Index(['DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime', 'ArrDelayMinutes',
#        'AirTime', 'CRSElapsedTime', 'ActualElapsedTime', 'Tail_Number',
#        'DepDel15', 'DepartureDelayGroups', 'TaxiOut', 'WheelsOff', 'WheelsOn',
#        'TaxiIn', 'ArrDelay', 'ArrDel15', 'ArrivalDelayGroups',
#        'DivAirportLandings'],
#       dtype='object')

# %%
df[df['AirTime'].isna() == True]['Cancelled'].value_counts()
# Out:
# True     88373
# False    20898
# Name: Cancelled, dtype: int64

# %% [markdown]
# ## 결측치가 있는 데이터들의 정답값 분포 확인
#
# ### (y값은 총 88373개)

# %%
for i in df_na.columns:
    print('column :', i)
    print(df[df[i].isna() == True]['Cancelled'].value_counts())
    print('')
# Out:
# column : DepTime
# True     85360
# False       20
# Name: Cancelled, dtype: int64
#
# column : DepDelayMinutes
# True     85462
# False     1113
# Name: Cancelled, dtype: int64
#
# column : DepDelay
# True     85462
# False     1113
# Name: Cancelled, dtype: int64
#
# column : ArrTime
# True     88364
# False     2251
# Name: Cancelled, dtype: int64
#
# column : ArrDelayMinutes
# True     88373
# False    14520
# Name: Cancelled, dtype: int64
#
# column : AirTime
# True     88373
# False    20898
# Name: Cancelled, dtype: int64
#
# column : CRSElapsedTime
# False    3
# True     3
# Name: Cancelled, dtype: int64
#
# column : ActualElapsedTime
# True     88373
# False    13974
# Name: Cancelled, dtype: int64
#
# column : Tail_Number
# True     20529
# False       19
# Name: Cancelled, dtype: int64
#
# column : DepDel15
# True     85462
# False     1113
# Name: Cancelled, dtype: int64
#
# column : DepartureDelayGroups
# True     85462
# False     1113
# Name: Cancelled, dtype: int64
# ...

# %% [markdown]
# ## ArrDelayMinutes, AirTime, ActualElapsedTime, TaxiIn, ArrDelay, ArrDel15, ArrivalDelayGroups 컬럼
#
# ### 위 컬럼들은 결측치를 보유한 행만 정답값이 1임. 즉, 결측치가 아니면서 정답값이 1인 분포가 없음 -> 결측치를 채울 수가 없다. 따라서 컬럼 삭제

# %% [markdown]
# ## 'DepTime' , 'DepDelayMinutes', 'DepDelay' , 'ArrTime' , 'DepDel15' , 'DepartureDelayGroups' , TaxiOut , 'WheelsOff' , ' WheelsOn' , 컬럼

# %% [markdown]
# ### 이 컬럼들 역시 결측치 대부분이 정답값에 분포함. 결측치를 통계적으로 의미있게 채워넣기 힘듦, 오히려  정확도를 해칠 수도

# %%
df = df.drop(columns = ['ArrDelayMinutes', 'AirTime', 'ActualElapsedTime', 'TaxiIn', 'ArrDelay', 'ArrDel15', 'ArrivalDelayGroups'])

# %%
df = df.drop(columns = ['DepTime' , 'DepDelayMinutes', 'DepDelay' , 'ArrTime' , 'DepDel15' , 'DepartureDelayGroups' , 'TaxiOut' , 'WheelsOff' , 'WheelsOn'])

# %%
df
# Out:
#          FlightDate                      Airline Origin Dest  Cancelled  \
# 0        2018-01-23            Endeavor Air Inc.    ABY  ATL      False
# 1        2018-01-24            Endeavor Air Inc.    ABY  ATL      False
# 2        2018-01-25            Endeavor Air Inc.    ABY  ATL      False
# 3        2018-01-26            Endeavor Air Inc.    ABY  ATL      False
# 4        2018-01-27            Endeavor Air Inc.    ABY  ATL      False
# ...             ...                          ...    ...  ...        ...
# 5689507  2018-09-11  Air Wisconsin Airlines Corp    SCE  IAD      False
# 5689508  2018-09-11  Air Wisconsin Airlines Corp    IAD  GSO      False
# 5689509  2018-09-11  Air Wisconsin Airlines Corp    EVV  ORD      False
# 5689510  2018-09-11  Air Wisconsin Airlines Corp    ORD  HPN      False
# 5689511  2018-09-11  Air Wisconsin Airlines Corp    HPN  ORD      False
#
#          Diverted  CRSDepTime  CRSElapsedTime  Distance  Year  ...  \
# ...

# %% [markdown]
# ## 나머지 결측치

# %%
np.where(df.isna().sum() != 0)
# Out:
# (array([ 7, 22, 44], dtype=int64),)

# %%
df_na = df.iloc[:,[7,22,44]]

# %%
df_na.isna().sum()
# Out:
# CRSElapsedTime            6
# Tail_Number           20548
# DivAirportLandings        1
# dtype: int64

# %%
df['Tail_Number'].value_counts()
# Out:
# N491HA    3810
# N495HA    3695
# N494HA    3692
# N477HA    3601
# N486HA    3589
#           ...
# N802NW       1
# N274AY       1
# N864DA       1
# N805H        1
# N724AN       1
# Name: Tail_Number, Length: 6093, dtype: int64

# %% [markdown]
# ## 'Tail_Number' 컬럼도 레벨이 너무 다양하고 결측치의 정답값의 비율이 너무 높아 삭제
# ## 나머지 두 컬럼의 결측치는 개수가 너무 적어 데이터를 날림

# %%
df = df.drop(columns = 'Tail_Number')

# %%
df = df.dropna()

# %% [markdown]
# # 데이터 전처리(인코딩 및 컬럼 간소화)

# %% [markdown]
# ## 컬럼 설명서를 봤을 때, 비슷한 내용을 가진 컬럼도 있었고, 이미 인코딩 된 것 같은 컬럼도 있었음

# %% [markdown]
# ### 날짜를 나타내는 컬럼들

# %%
df_date = df[['FlightDate','Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'Cancelled']]

# %%
df['FlightDate'].unique()
# Out:
# array(['2018-01-23', '2018-01-24', '2018-01-25', '2018-01-26',
#        '2018-01-27', '2018-01-28', '2018-01-29', '2018-01-30',
#        '2018-01-31', '2018-01-03', '2018-01-04', '2018-01-05',
#        '2018-01-06', '2018-01-07', '2018-01-08', '2018-01-09',
#        '2018-01-10', '2018-01-11', '2018-01-12', '2018-01-13',
#        '2018-01-14', '2018-01-15', '2018-01-16', '2018-01-17',
#        '2018-01-18', '2018-01-19', '2018-01-20', '2018-01-21',
#        '2018-01-22', '2018-01-01', '2018-01-02', '2018-10-05',
#        '2018-10-06', '2018-10-07', '2018-10-16', '2018-10-17',
#        '2018-10-18', '2018-10-19', '2018-10-20', '2018-10-21',
#        '2018-10-22', '2018-10-01', '2018-10-29', '2018-10-30',
#        '2018-10-10', '2018-10-11', '2018-10-12', '2018-10-13',
#        '2018-10-14', '2018-10-15', '2018-10-23', '2018-10-08',
#        '2018-10-09', '2018-10-28', '2018-10-27', '2018-10-24',
#        '2018-10-04', '2018-10-25', '2018-10-26', '2018-10-02',
# ...

# %% [markdown]
# - FlightDate 삭제 (Countable한 데이터인데 그 종류가 너무 많고, 이미 다른 컬럼들로 세분화 되어 인코딩 된 상황)
# - Year 삭제 (2018로 모두 동일, 독립변수로 기능 못함)

# %%
df = df.drop(columns = ['FlightDate','Year'])
df_date = df_date.drop(columns = ['FlightDate','Year'])

# %% [markdown]
# ### 나머지 컬럼들과 정답 레이블 간의 상관관계 파악

# %%
df['Cancelled'].unique()
# Out:
# array([False,  True])

# %%
df_date.corr()
# Out:
#              Quarter     Month  DayofMonth  DayOfWeek  Cancelled
# Quarter     1.000000  0.971604    0.006832   0.007626  -0.032433
# Month       0.971604  1.000000    0.007349   0.019599  -0.030138
# DayofMonth  0.006832  0.007349    1.000000   0.007944  -0.021850
# DayOfWeek   0.007626  0.019599    0.007944   1.000000  -0.010526
# Cancelled  -0.032433 -0.030138   -0.021850  -0.010526   1.000000

# %% [markdown]
# ### 상관계수가 제일 높은 Quarter만 채택

# %%
df = df.drop(columns = ['Month','DayofMonth' ,'DayOfWeek'])

# %%
df
# Out:
#                              Airline Origin Dest  Cancelled  Diverted  \
# 0                  Endeavor Air Inc.    ABY  ATL      False     False
# 1                  Endeavor Air Inc.    ABY  ATL      False     False
# 2                  Endeavor Air Inc.    ABY  ATL      False     False
# 3                  Endeavor Air Inc.    ABY  ATL      False     False
# 4                  Endeavor Air Inc.    ABY  ATL      False     False
# ...                              ...    ...  ...        ...       ...
# 5689507  Air Wisconsin Airlines Corp    SCE  IAD      False     False
# 5689508  Air Wisconsin Airlines Corp    IAD  GSO      False     False
# 5689509  Air Wisconsin Airlines Corp    EVV  ORD      False     False
# 5689510  Air Wisconsin Airlines Corp    ORD  HPN      False     False
# 5689511  Air Wisconsin Airlines Corp    HPN  ORD      False     False
#
#          CRSDepTime  CRSElapsedTime  Distance  Quarter  \
# 0              1202            62.0     145.0        1
# ...

# %%
df.describe(include = 'all')
# Out:
#                        Airline   Origin     Dest Cancelled Diverted  \
# count                  5689505  5689505  5689505   5689505  5689505
# unique                      28      370      370         2        2
# top     Southwest Airlines Co.      ORD      ORD     False    False
# freq                   1352552   289451   289405   5601136  5675553
# mean                       NaN      NaN      NaN       NaN      NaN
# std                        NaN      NaN      NaN       NaN      NaN
# min                        NaN      NaN      NaN       NaN      NaN
# 25%                        NaN      NaN      NaN       NaN      NaN
# 50%                        NaN      NaN      NaN       NaN      NaN
# 75%                        NaN      NaN      NaN       NaN      NaN
# max                        NaN      NaN      NaN       NaN      NaN
#
#           CRSDepTime  CRSElapsedTime      Distance       Quarter  \
# count   5.689505e+06    5.689505e+06  5.689505e+06  5.689505e+06
# ...

# %%
df.columns
# Out:
# Index(['Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted', 'CRSDepTime',
#        'CRSElapsedTime', 'Distance', 'Quarter', 'Marketing_Airline_Network',
#        'Operated_or_Branded_Code_Share_Partners', 'DOT_ID_Marketing_Airline',
#        'IATA_Code_Marketing_Airline', 'Flight_Number_Marketing_Airline',
#        'Operating_Airline', 'DOT_ID_Operating_Airline',
#        'IATA_Code_Operating_Airline', 'Flight_Number_Operating_Airline',
#        'OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID',
#        'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName',
#        'OriginWac', 'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID',
#        'DestCityName', 'DestState', 'DestStateFips', 'DestStateName',
#        'DestWac', 'DepTimeBlk', 'CRSArrTime', 'ArrTimeBlk', 'DistanceGroup',
#        'DivAirportLandings'],
#       dtype='object')

# %% [markdown]
# ## Origin 관련 컬럼들

# %%
df_origin = df[['Origin','OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID',
       'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName',
       'OriginWac']]

# %%
df_origin
# Out:
#         Origin  OriginAirportID  OriginAirportSeqID  OriginCityMarketID  \
# 0          ABY            10146             1014602               30146
# 1          ABY            10146             1014602               30146
# 2          ABY            10146             1014602               30146
# 3          ABY            10146             1014602               30146
# 4          ABY            10146             1014602               30146
# ...        ...              ...                 ...                 ...
# 5689507    SCE            14711             1471105               34711
# 5689508    IAD            12264             1226402               30852
# 5689509    EVV            11612             1161206               31612
# 5689510    ORD            13930             1393006               30977
# 5689511    HPN            12197             1219702               31703
#
#             OriginCityName OriginState  OriginStateFips OriginStateName  \
# ...

# %%
for i in df_origin.columns:
    print('column :' ,i)
    print(df_origin[i].unique())
    print('unique 개수 :', len(df_origin[i].unique()))
    print('')
# Out:
# column : Origin
# ['ABY' 'ATL' 'MOB' 'BUF' 'DFW' 'BTV' 'CVG' 'LGA' 'CHO' 'EWN' 'MCI' 'MGM'
#  'MSP' 'DCA' 'FAY' 'OAJ' 'STL' 'CWA' 'DTW' 'RDU' 'SRQ' 'AEX' 'AUS' 'CSG'
#  'EVV' 'IND' 'CLE' 'PIA' 'TRI' 'BGR' 'IAD' 'PWM' 'TYS' 'GSO' 'AVL' 'BTR'
#  'MKE' 'CMH' 'GRR' 'GSP' 'BIS' 'ORD' 'ROC' 'CHA' 'TVC' 'FSM' 'JAX' 'BOS'
#  'GRB' 'TUL' 'VLD' 'CRW' 'IAH' 'XNA' 'JAN' 'SAV' 'CHS' 'ROA' 'GFK' 'SYR'
#  'MDT' 'SAT' 'BMI' 'LFT' 'BNA' 'PHL' 'BQK' 'ORF' 'GNV' 'OMA' 'TPA' 'BWI'
#  'MEM' 'MBS' 'SDF' 'LEX' 'CLT' 'DAY' 'MOT' 'FAR' 'CAE' 'DSM' 'PIT' 'DHN'
#  'MHT' 'ILM' 'SGF' 'ELM' 'BDL' 'MCO' 'RIC' 'SHV' 'MSY' 'HSV' 'TLH' 'LAN'
#  'LIT' 'GRK' 'MSN' 'ATW' 'HRL' 'HPN' 'CAK' 'EWR' 'RSW' 'BQN' 'PBI' 'FLL'
#  'SLC' 'PSE' 'JFK' 'SJC' 'LAS' 'LGB' 'LAX' 'SFO' 'SJU' 'HOU' 'DEN' 'SEA'
#  'STT' 'PVD' 'PDX' 'SAN' 'RNO' 'ALB' 'PHX' 'OAK' 'PSP' 'SMF' 'STX' 'BUR'
#  'SWF' 'DAB' 'ORH' 'ABQ' 'ELP' 'LCH' 'HOB' 'PNS' 'COS' 'ICT' 'CLL' 'OKC'
#  'ECP' 'MFE' 'MYR' 'BHM' 'AGS' 'AZO' 'GPT' 'RST' 'VPS' 'EYW' 'PHF' 'ABE'
# ...

# %% [markdown]
# ### Origin -> OriginAirportID 인코딩 됨
# ### OriginState, OriginStateFips, OriginStateName -> OriginWac 인코딩 됨
# ### OriginCityName -> OriginWac 안에 범주 간소화 되어 인코딩 됨

# %%
df = df.drop(columns = ['Origin', 'OriginState', 'OriginStateFips', 'OriginStateName' , 'OriginCityName'])

# %%
df_origin = df_origin.drop(columns = ['Origin', 'OriginState', 'OriginStateFips', 'OriginStateName' , 'OriginCityName'])

# %%
df_origin['Cancelled'] = df['Cancelled']

# %%
df_origin.corr()
# Out:
#                     OriginAirportID  OriginAirportSeqID  OriginCityMarketID  \
# OriginAirportID            1.000000            1.000000            0.610361
# OriginAirportSeqID         1.000000            1.000000            0.610361
# OriginCityMarketID         0.610361            0.610361            1.000000
# OriginWac                  0.259501            0.259501            0.077243
# Cancelled                 -0.009992           -0.009992           -0.001515
#
#                     OriginWac  Cancelled
# OriginAirportID      0.259501  -0.009992
# OriginAirportSeqID   0.259501  -0.009992
# OriginCityMarketID   0.077243  -0.001515
# OriginWac            1.000000  -0.038613
# Cancelled           -0.038613   1.000000

# %% [markdown]
# ### 상관계수 제일 높은 OriginWac만 채택

# %%
df = df.drop(columns = ['OriginAirportID','OriginAirportSeqID','OriginCityMarketID'])

# %%
df
# Out:
#                              Airline Dest  Cancelled  Diverted  CRSDepTime  \
# 0                  Endeavor Air Inc.  ATL      False     False        1202
# 1                  Endeavor Air Inc.  ATL      False     False        1202
# 2                  Endeavor Air Inc.  ATL      False     False        1202
# 3                  Endeavor Air Inc.  ATL      False     False        1202
# 4                  Endeavor Air Inc.  ATL      False     False        1400
# ...                              ...  ...        ...       ...         ...
# 5689507  Air Wisconsin Airlines Corp  IAD      False     False        1445
# 5689508  Air Wisconsin Airlines Corp  GSO      False     False        1235
# 5689509  Air Wisconsin Airlines Corp  ORD      False     False        1030
# 5689510  Air Wisconsin Airlines Corp  HPN      False     False        1410
# 5689511  Air Wisconsin Airlines Corp  ORD      False     False        1800
#
# ...

# %% [markdown]
# ## destination 관련 컬럼들

# %%
df_dest = df[['Dest', 'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID',
       'DestCityName', 'DestState', 'DestStateFips', 'DestStateName',
       'DestWac']]

# %%
df_dest
# Out:
#         Dest  DestAirportID  DestAirportSeqID  DestCityMarketID  \
# 0        ATL          10397           1039707             30397
# 1        ATL          10397           1039707             30397
# 2        ATL          10397           1039707             30397
# 3        ATL          10397           1039707             30397
# 4        ATL          10397           1039707             30397
# ...      ...            ...               ...               ...
# 5689507  IAD          12264           1226402             30852
# 5689508  GSO          11995           1199502             31995
# 5689509  ORD          13930           1393006             30977
# 5689510  HPN          12197           1219702             31703
# 5689511  ORD          13930           1393006             30977
#
#                       DestCityName DestState  DestStateFips   DestStateName  \
# 0                      Atlanta, GA        GA             13         Georgia
# ...

# %%
for i in df_dest.columns:
    print('column :' ,i)
    print(df_dest[i].unique())
    print('unique 개수 :', len(df_dest[i].unique()))
    print('')
# Out:
# column : Dest
# ['ATL' 'ABY' 'MOB' 'EVV' 'DTW' 'OAJ' 'BOS' 'SYR' 'EWN' 'MGM' 'LGA' 'MSP'
#  'CLE' 'CLT' 'FAY' 'JFK' 'STL' 'CMH' 'IND' 'TYS' 'CWA' 'AEX' 'GRK' 'SAT'
#  'PIA' 'IAH' 'DFW' 'RIC' 'PWM' 'AZO' 'CVG' 'TRI' 'IAD' 'AVL' 'BTR' 'BUF'
#  'GRR' 'BIS' 'CHA' 'TVC' 'FSM' 'BTV' 'MCI' 'GRB' 'TUL' 'VLD' 'CRW' 'XNA'
#  'ROC' 'SAV' 'ROA' 'MDT' 'MSY' 'BNA' 'RDU' 'MKE' 'GNV' 'TPA' 'GSO' 'CHO'
#  'BGR' 'GFK' 'BQK' 'MEM' 'ILM' 'BMI' 'ORF' 'MHT' 'DAY' 'GSP' 'LEX' 'SDF'
#  'BDL' 'MBS' 'MOT' 'CAE' 'CSG' 'DSM' 'DHN' 'ELM' 'PIT' 'JAX' 'DCA' 'ORD'
#  'SGF' 'SHV' 'HSV' 'OMA' 'TLH' 'MSN' 'LAN' 'BWI' 'CHS' 'LIT' 'RSW' 'MCO'
#  'FAR' 'ATW' 'CAK' 'HRL' 'HPN' 'PHL' 'MLI' 'BQN' 'SFO' 'EWR' 'FLL' 'SLC'
#  'PSE' 'SJC' 'LGB' 'LAS' 'LAX' 'PBI' 'SJU' 'SRQ' 'AUS' 'SWF' 'DEN' 'SEA'
#  'HOU' 'PVD' 'SMF' 'STT' 'PDX' 'ORH' 'SAN' 'RNO' 'ALB' 'PHX' 'OAK' 'PSP'
#  'STX' 'BUR' 'DAB' 'ABQ' 'BRO' 'ELP' 'OKC' 'GPT' 'SBN' 'MFE' 'LCH' 'LFT'
#  'MYR' 'RST' 'LNK' 'BHM' 'AGS' 'JAN' 'CID' 'ECP' 'VPS' 'EYW' 'ABE' 'SFB'
# ...

# %% [markdown]
# ### Dest -> DestAirportID 인코딩 됨
# ### DestState, DestStateFips, DestStateName -> DestWac 인코딩 됨
# ### DestCityName -> OriginWac 안에 범주 간소화 되어 인코딩 됨

# %%
df = df.drop(columns = ['Dest','DestState', 'DestStateFips', 'DestStateName' ,'DestCityName' ])

# %%
df_dest = df_dest.drop(columns = ['Dest','DestState', 'DestStateFips', 'DestStateName' ,'DestCityName' ])

# %%
df_dest.corr()
# Out:
#                   DestAirportID  DestAirportSeqID  DestCityMarketID   DestWac
# DestAirportID          1.000000          1.000000          0.610360  0.259498
# DestAirportSeqID       1.000000          1.000000          0.610360  0.259498
# DestCityMarketID       0.610360          0.610360          1.000000  0.077221
# DestWac                0.259498          0.259498          0.077221  1.000000

# %%
df_dest['Cancelled'] = df['Cancelled']

# %%
df_dest.corr()
# Out:
#                   DestAirportID  DestAirportSeqID  DestCityMarketID   DestWac  \
# DestAirportID          1.000000          1.000000          0.610360  0.259498
# DestAirportSeqID       1.000000          1.000000          0.610360  0.259498
# DestCityMarketID       0.610360          0.610360          1.000000  0.077221
# DestWac                0.259498          0.259498          0.077221  1.000000
# Cancelled             -0.010968         -0.010968         -0.005566 -0.037664
#
#                   Cancelled
# DestAirportID     -0.010968
# DestAirportSeqID  -0.010968
# DestCityMarketID  -0.005566
# DestWac           -0.037664
# Cancelled          1.000000

# %% [markdown]
# ### 상관계수 제일 높은 DestWac만 채택

# %%
df = df.drop(columns = ['DestAirportID','DestAirportSeqID','DestCityMarketID'])

# %% [markdown]
# ## 문자형 컬럼 인코딩

# %%
df.dtypes
# Out:
# Airline                                     object
# Cancelled                                     bool
# Diverted                                      bool
# CRSDepTime                                   int64
# CRSElapsedTime                             float64
# Distance                                   float64
# Quarter                                      int64
# Marketing_Airline_Network                   object
# Operated_or_Branded_Code_Share_Partners     object
# DOT_ID_Marketing_Airline                     int64
# IATA_Code_Marketing_Airline                 object
# Flight_Number_Marketing_Airline              int64
# Operating_Airline                           object
# DOT_ID_Operating_Airline                     int64
# IATA_Code_Operating_Airline                 object
# Flight_Number_Operating_Airline              int64
# OriginWac                                    int64
# DestWac                                      int64
# ...

# %%
df['CRSElapsedTime'] = df['CRSElapsedTime'].astype('int64')
df['Distance'] = df['Distance'].astype('int64')
df['DivAirportLandings'] = df['DivAirportLandings'].astype('int64')

# %%
df.dtypes
# Out:
# Airline                                    object
# Cancelled                                    bool
# Diverted                                     bool
# CRSDepTime                                  int64
# CRSElapsedTime                              int64
# Distance                                    int64
# Quarter                                     int64
# Marketing_Airline_Network                  object
# Operated_or_Branded_Code_Share_Partners    object
# DOT_ID_Marketing_Airline                    int64
# IATA_Code_Marketing_Airline                object
# Flight_Number_Marketing_Airline             int64
# Operating_Airline                          object
# DOT_ID_Operating_Airline                    int64
# IATA_Code_Operating_Airline                object
# Flight_Number_Operating_Airline             int64
# OriginWac                                   int64
# DestWac                                     int64
# DepTimeBlk                                 object
# ...

# %% [markdown]
# ### 문자형 데이터만 추출

# %%
obj_columns = []

for i in df.columns:
    if df[i].dtype == 'object':
        obj_columns.append(i)

# %%
df_obj = df[obj_columns]

# %%
df_obj
# Out:
#                              Airline Marketing_Airline_Network  \
# 0                  Endeavor Air Inc.                        DL
# 1                  Endeavor Air Inc.                        DL
# 2                  Endeavor Air Inc.                        DL
# 3                  Endeavor Air Inc.                        DL
# 4                  Endeavor Air Inc.                        DL
# ...                              ...                       ...
# 5689507  Air Wisconsin Airlines Corp                        UA
# 5689508  Air Wisconsin Airlines Corp                        UA
# 5689509  Air Wisconsin Airlines Corp                        UA
# 5689510  Air Wisconsin Airlines Corp                        UA
# 5689511  Air Wisconsin Airlines Corp                        UA
#
#         Operated_or_Branded_Code_Share_Partners IATA_Code_Marketing_Airline  \
# 0                                  DL_CODESHARE                          DL
# ...

# %%
for i in df_obj.columns:
    print('column :' ,i)
    print(df_obj[i].unique())
    print('unique 개수 :', len(df_obj[i].unique()))
    print('')
# Out:
# column : Airline
# ['Endeavor Air Inc.' 'JetBlue Airways' 'ExpressJet Airlines Inc.'
#  'Allegiant Air' 'Hawaiian Airlines Inc.' 'Spirit Air Lines'
#  'SkyWest Airlines Inc.' 'Frontier Airlines Inc.' 'Empire Airlines Inc.'
#  'Southwest Airlines Co.' 'Mesa Airlines Inc.' 'Republic Airlines'
#  'Delta Air Lines Inc.' 'United Air Lines Inc.' 'Alaska Airlines Inc.'
#  'Horizon Air' 'Commutair Aka Champlain Enterprises, Inc.'
#  'Trans States Airlines' 'GoJet Airlines, LLC d/b/a United Express'
#  'Air Wisconsin Airlines Corp' 'Cape Air' 'Compass Airlines'
#  'Virgin America' 'Peninsula Airways Inc.' 'Envoy Air'
#  'American Airlines Inc.' 'Comair Inc.' 'Capital Cargo International']
# unique 개수 : 28
#
# column : Marketing_Airline_Network
# ['DL' 'B6' 'UA' 'G4' 'HA' 'NK' 'AS' 'F9' 'WN' 'VX' 'AA']
# unique 개수 : 11
#
# column : Operated_or_Branded_Code_Share_Partners
# ['DL_CODESHARE' 'B6' 'UA_CODESHARE' 'G4' 'HA' 'NK' 'AS_CODESHARE' 'F9'
# ...

# %%
df['Marketing_Airline_Network'].value_counts()
# Out:
# UA    1525257
# WN    1352552
# AA     856113
# DL     838465
# AS     309195
# B6     305010
# NK     176178
# F9     120034
# G4      96221
# HA      92810
# VX      17670
# Name: Marketing_Airline_Network, dtype: int64

# %%
df['IATA_Code_Marketing_Airline'].value_counts()
# Out:
# UA    1525257
# WN    1352552
# AA     856113
# DL     838465
# AS     309195
# B6     305010
# NK     176178
# F9     120034
# G4      96221
# HA      92810
# VX      17670
# Name: IATA_Code_Marketing_Airline, dtype: int64

# %%
df['Airline'].value_counts()
# Out:
# Southwest Airlines Co.                       1352552
# United Air Lines Inc.                         621565
# SkyWest Airlines Inc.                         531792
# Delta Air Lines Inc.                          461718
# American Airlines Inc.                        385183
# JetBlue Airways                               305010
# Republic Airlines                             203526
# Alaska Airlines Inc.                          184751
# Spirit Air Lines                              176178
# ExpressJet Airlines Inc.                      167180
# Mesa Airlines Inc.                            153694
# Envoy Air                                     127750
# Frontier Airlines Inc.                        120034
# Endeavor Air Inc.                             120030
# Comair Inc.                                   117132
# Air Wisconsin Airlines Corp                    98763
# Allegiant Air                                  96221
# Horizon Air                                    85245
# ...

# %%
df['Operating_Airline'].value_counts()
# Out:
# WN    1352552
# UA     621565
# OO     531792
# DL     461718
# AA     385183
# B6     305010
# YX     203526
# AS     184751
# NK     176178
# EV     167180
# YV     153694
# MQ     127750
# F9     120034
# 9E     120030
# OH     117132
# ZW      98763
# G4      96221
# QX      85245
# HA      83723
# AX      66885
# G7      63498
# C5      48010
# CP      44898
# PT      44440
# VX      17670
# EM       9087
# 9K       1661
# KS       1309
# Name: Operating_Airline, dtype: int64

# %% [markdown]
# ### Operating_Airline 컬럼, IATA_Code_Operating_Airline , Airline컬럼은 같은 컬럼
# ### IATA_Code_Marketing_Airline, Marketing_Airline_Network 컬럼도 같은 컬럼

# %%
df = df.drop(columns = ['Airline' , 'IATA_Code_Operating_Airline' , 'IATA_Code_Marketing_Airline'])

# %%
df_obj = df_obj.drop(columns = ['Airline' , 'IATA_Code_Operating_Airline' , 'IATA_Code_Marketing_Airline'])

# %%
df_obj
# Out:
#         Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                              DL                            DL_CODESHARE
# 1                              DL                            DL_CODESHARE
# 2                              DL                            DL_CODESHARE
# 3                              DL                            DL_CODESHARE
# 4                              DL                            DL_CODESHARE
# ...                           ...                                     ...
# 5689507                        UA                            UA_CODESHARE
# 5689508                        UA                            UA_CODESHARE
# 5689509                        UA                            UA_CODESHARE
# 5689510                        UA                            UA_CODESHARE
# 5689511                        UA                            UA_CODESHARE
#
#         Operating_Airline DepTimeBlk ArrTimeBlk
# ...

# %% [markdown]
# ### 인코딩

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(df['Marketing_Airline_Network'])
df['Marketing_Airline_Network'] = encoder.transform(df['Marketing_Airline_Network'])

# %%
encoder.fit(df['Operated_or_Branded_Code_Share_Partners'])
df['Operated_or_Branded_Code_Share_Partners'] = encoder.transform(df['Operated_or_Branded_Code_Share_Partners'])

# %%
encoder.fit(df['Operating_Airline'])
df['Operating_Airline'] = encoder.transform(df['Operating_Airline'])

# %%
encoder.fit(df['DepTimeBlk'])
df['DepTimeBlk'] = encoder.transform(df['DepTimeBlk'])

# %%
encoder.fit(df['ArrTimeBlk'])
df['ArrTimeBlk'] = encoder.transform(df['ArrTimeBlk'])

# %%
df.dtypes
# Out:
# Cancelled                                   bool
# Diverted                                    bool
# CRSDepTime                                 int64
# CRSElapsedTime                             int64
# Distance                                   int64
# Quarter                                    int64
# Marketing_Airline_Network                  int32
# Operated_or_Branded_Code_Share_Partners    int32
# DOT_ID_Marketing_Airline                   int64
# Flight_Number_Marketing_Airline            int64
# Operating_Airline                          int32
# DOT_ID_Operating_Airline                   int64
# Flight_Number_Operating_Airline            int64
# OriginWac                                  int64
# DestWac                                    int64
# DepTimeBlk                                 int32
# CRSArrTime                                 int64
# ArrTimeBlk                                 int32
# DistanceGroup                              int64
# ...

# %% [markdown]
# ## 인코딩 끝, 마지막으로 나머지 컬럼들 중 중복되는 컬럼이 없는지 확인

# %%
df['Diverted'].value_counts()
# Out:
# False    5675553
# True       13952
# Name: Diverted, dtype: int64

# %%
df['Cancelled'].value_counts()
# Out:
# False    5601136
# True       88369
# Name: Cancelled, dtype: int64

# %%
int64_columns = []

for i in df.columns:
    if df[i].dtype == 'int64':
        int64_columns.append(i)

# %%
df_int64 = df[int64_columns]

# %%
df_int64
# Out:
#          CRSDepTime  CRSElapsedTime  Distance  Quarter  \
# 0              1202              62       145        1
# 1              1202              62       145        1
# 2              1202              62       145        1
# 3              1202              62       145        1
# 4              1400              60       145        1
# ...             ...             ...       ...      ...
# 5689507        1445              61       133        3
# 5689508        1235              80       239        3
# 5689509        1030              94       272        3
# 5689510        1410             136       738        3
# 5689511        1800             153       738        3
#
#          DOT_ID_Marketing_Airline  Flight_Number_Marketing_Airline  \
# 0                           19790                             3298
# 1                           19790                             3298
# 2                           19790                             3298
# ...

# %%
for i in df_int64:
    print('column :' ,i)
    print(df_int64[i].unique())
    print('unique 개수 :', len(df_int64[i].unique()))
    print('')
# Out:
# column : CRSDepTime
# [1202 1400 1037 ...  122  121  134]
# unique 개수 : 1366
#
# column : CRSElapsedTime
# [  62   60   59   88   89   83   76   87   84  166   85  135  129   78
#    79   81  110   90   66  125  152   80   97  180  114  113  107  102
#    73  104   70  119  118  157  199  168  105  117  122   94  106  143
#    56   55  202  115  120   93   98   74  100  124   99   95   77   86
#   123  121  109   67   92  101  132   82  134  111   61   68  116  127
#   112  128   65  148  231  103  136   57  175   63  169  158  205  108
#   171   54   75  182   58  226  220  224   69  140  151  126   64   71
#   159  165  162   96   91  133  237  138  145  131   72  179  195  147
#   141  137  163  207  188   46   52   51  144   49  176  167  191  142
#   150  173  130   53  174  153  198  204  190  172  146  149  156  161
#   208  212  214  139  177  189  215  209  170  206  193  155  194  187
#   160  420  337  268  196  178  222  185  402  326  216  408  321  288
# ...

# %% [markdown]
# # 중복없음, 인코딩 끝!

# %%
df
# Out:
#          Cancelled  Diverted  CRSDepTime  CRSElapsedTime  Distance  Quarter  \
# 0            False     False        1202              62       145        1
# 1            False     False        1202              62       145        1
# 2            False     False        1202              62       145        1
# 3            False     False        1202              62       145        1
# 4            False     False        1400              60       145        1
# ...            ...       ...         ...             ...       ...      ...
# 5689507      False     False        1445              61       133        3
# 5689508      False     False        1235              80       239        3
# 5689509      False     False        1030              94       272        3
# 5689510      False     False        1410             136       738        3
# 5689511      False     False        1800             153       738        3
#
# ...

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_ = MinMaxScaler()
scaler_.fit(df)
df_scaled_ = scaler_.transform(df)

# %%
df_final = pd.DataFrame(df_scaled_, columns = df.columns)

# %%
df_final
# Out:
#          Cancelled  Diverted  CRSDepTime  CRSElapsedTime  Distance   Quarter  \
# 0              0.0       0.0    0.509330        0.092317  0.025971  0.000000
# 1              0.0       0.0    0.509330        0.092317  0.025971  0.000000
# 2              0.0       0.0    0.509330        0.092317  0.025971  0.000000
# 3              0.0       0.0    0.509330        0.092317  0.025971  0.000000
# 4              0.0       0.0    0.593299        0.091170  0.025971  0.000000
# ...            ...       ...         ...             ...       ...       ...
# 5689500        0.0       0.0    0.612383        0.091743  0.023555  0.666667
# 5689501        0.0       0.0    0.523325        0.102638  0.044896  0.666667
# 5689502        0.0       0.0    0.436387        0.110665  0.051540  0.666667
# 5689503        0.0       0.0    0.597540        0.134748  0.145359  0.666667
# 5689504        0.0       0.0    0.762935        0.144495  0.145359  0.666667
#
# ...

# %%
df
# Out:
#          Cancelled  Diverted  CRSDepTime  CRSElapsedTime  Distance  Quarter  \
# 0            False     False        1202              62       145        1
# 1            False     False        1202              62       145        1
# 2            False     False        1202              62       145        1
# 3            False     False        1202              62       145        1
# 4            False     False        1400              60       145        1
# ...            ...       ...         ...             ...       ...      ...
# 5689507      False     False        1445              61       133        3
# 5689508      False     False        1235              80       239        3
# 5689509      False     False        1030              94       272        3
# 5689510      False     False        1410             136       738        3
# 5689511      False     False        1800             153       738        3
#
# ...

# %%
df.dtypes
# Out:
# Cancelled                                   bool
# Diverted                                    bool
# CRSDepTime                                 int64
# CRSElapsedTime                             int64
# Distance                                   int64
# Quarter                                    int64
# Marketing_Airline_Network                  int32
# Operated_or_Branded_Code_Share_Partners    int32
# DOT_ID_Marketing_Airline                   int64
# Flight_Number_Marketing_Airline            int64
# Operating_Airline                          int32
# DOT_ID_Operating_Airline                   int64
# Flight_Number_Operating_Airline            int64
# OriginWac                                  int64
# DestWac                                    int64
# DepTimeBlk                                 int32
# CRSArrTime                                 int64
# ArrTimeBlk                                 int32
# DistanceGroup                              int64
# ...

# %%
df_final['Cancelled'] = df_final['Cancelled'].astype('int64')

# %%
df_final['Diverted'] = df_final['Diverted'].astype('int64')

# %%
df_final
# Out:
#          Cancelled  Diverted  CRSDepTime  CRSElapsedTime  Distance   Quarter  \
# 0                0         0    0.509330        0.092317  0.025971  0.000000
# 1                0         0    0.509330        0.092317  0.025971  0.000000
# 2                0         0    0.509330        0.092317  0.025971  0.000000
# 3                0         0    0.509330        0.092317  0.025971  0.000000
# 4                0         0    0.593299        0.091170  0.025971  0.000000
# ...            ...       ...         ...             ...       ...       ...
# 5689500          0         0    0.612383        0.091743  0.023555  0.666667
# 5689501          0         0    0.523325        0.102638  0.044896  0.666667
# 5689502          0         0    0.436387        0.110665  0.051540  0.666667
# 5689503          0         0    0.597540        0.134748  0.145359  0.666667
# 5689504          0         0    0.762935        0.144495  0.145359  0.666667
#
# ...

# %%
df_final.to_csv('df_final.csv')

# %% [markdown]
# ### 로지스틱 모델

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# 랜덤 포레스트 모델로부터 예측 확률을 얻어옴
y_pred_prob = rf_clf1.predict_proba(X_test)[:, 1]  # 양성 클래스의 확률을 사용

# 특정 임계값(0.01804)을 사용하여 이진 분류 예측 수행
threshold = 0.01804
y_pred = (y_pred_prob >= threshold).astype(int)

# 정확도, 정밀도, 재현율, F1 점수 계산
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'임계값 {threshold:.5f}일 때 - 정확도: {accuracy:.4f}, 정밀도: {precision:.4f}, 재현율: {recall:.4f}, F1 점수: {f1:.4f}')

# %%
def get_clf_eval(y_test, pred): # 혼동행렬
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도:{1:.4f}, 재현율:{2:.4f}'.format(accuracy, precision, recall))

# %%
from sklearn.linear_model import LogisticRegression

# %%
df_final = df_final.drop(columns="Unnamed: 0")

# %%
X_train, X_test, y_train, y_test = train_test_split(df_final.drop('Cancelled',axis=1), df_final['Cancelled'], test_size=0.3, random_state=111)

# %%
Ir_clf = LogisticRegression(solver = "saga")
Ir_clf.fit(X_train,y_train)
pred = Ir_clf.predict(X_test)
pred_proba = Ir_clf.predict_proba(X_test)

# %%
get_clf_eval(y_test,pred)

# %%
from sklearn.metrics import precision_recall_curve

#레이블 값이 1일때 예측확률을 추출
pred_proba_class1 = Ir_clf.predict_proba(X_test)[:,1]

# 실제값 데이터 세트와 레이블 값이 1일 때의 예측확률을 precision_recall_curve 인자로 입력 
precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_class1)
print('반환된 분류 결정 임곗값 배열의 shape:', thresholds.shape)

#반환된 임계값 배열 로우가 약 약 38만건이므로 샘플로 10건만 추출하되, 임곗값을 38,000 step으로 추출
thr_index = np.arange(0,thresholds.shape[0], 38000)
print('샘플 추출을 위한 임계값 배열의 index 10개:', thr_index)
print('샘플용 10개의 임곗값:', np.round(thresholds[thr_index],5))

# %%
from sklearn.preprocessing import Binarizer

# %%
def get_clf_eval(y_test, pred):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    #F1 스코어 추가
    f1 = f1_score(y_test, pred)
    print('오차 행렬')
    print(confusion)
    # f1 score print 추가 
    print('정확도:{0:.4f}, 정밀도:{1:.4f}, 재현율:{2:.4f}, F1:{3:.4f}'.format(accuracy, precision, recall, f1))
    print("")
    
def get_eval_by_threshold(y_test, pred_proba_c1, thresholds):
    #thresholds list 객체 내의 값을 차례로 iteration 하면서 Evaluation 수행.
    for custom_threshold in thresholds:
        binarizer = Binarizer(threshold=custom_threshold).fit(pred_proba_c1)
        custom_pred
        ict = binarizer.transform(pred_proba_c1)
        print('임곗값:', custom_threshold)
        get_clf_eval(y_test, custom_predict)

# 앞서 구한 샘플 임계치에 따른 정확도, 정밀도, 재현율, f1_score 구하기
thresholds = [0.00073, 0.00548, 0.0071,  0.00875, 0.01042, 0.01225, 0.01441, 0.01722, 0.02118, 0.02747, 0.05494, 0.01804]
get_eval_by_threshold(y_test, pred_proba[:,1].reshape(-1,1), thresholds)

# %%
from sklearn.metrics import precision_recall_curve

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

def precision_recall_curve_plot(y_test, pred_proba_c1):
    # thredshold ndarray와 이 threshold에 따른 정밀도, 재현율 ndarray 추출 
    precision, recalls, thresholds = precision_recall_curve(y_test, pred_proba_c1)
    
    #X축을 thredshold 값으로, Y축은 정밀도, 재현율 값으로 각각 plot 수행. 정밀도는 점선으로 표시 
    plt.figure(figsize=(15,15))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precision[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary], label ='recall')
    
    #thredshold 값 X축 Scale을 0.1단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    #X축, y축, label과 legend, 그리고 grid 설정
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend();plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test, Ir_clf.predict_proba(X_test)[:,1])

# %%
from sklearn.metrics import roc_curve

# %%
def roc_curve_plot(y_test, pred_proba_c1):
    #임곗값에 따른 FPR, TPR값을 반환받음.
    fprs, tprs, thresholds = roc_curve(y_test, pred_proba_c1)
    #ROC 곡선을 그래프 곡선으로 그림
    plt.plot(fprs, tprs, label='ROC')
    #가운데 대각선 직선을 그림
    plt.plot([0,1], [0,1], 'k--', label='Random')
    
    #FPR X축의 Scale을 0.1 단위로 변경, X,Y축 명 설정 등
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start,end,0.1),2))
    plt.xlim(0,1);plt.ylim(0,1)
    plt.xlabel('FPR(1-Specificity)');plt.ylabel('TPR(Recall)')
    plt.legend()
    

    
roc_curve_plot(y_test, pred_proba[:,1])

# %%
from sklearn.metrics import roc_auc_score

pred_proba = Ir_clf.predict_proba(X_test)[:,1]
roc_score = roc_auc_score(y_test, pred_proba)
print('ROC AUC 값:{0:.4f}'.format(roc_score))

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_proba) 
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print("Threshold value is:", np.round(optimal_threshold, 5))

# %% [markdown]
# ### Random Forest 모델

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, cross_validate

# %%
df_final_sp = df_final.drop('Unnamed: 0',axis=1)
df_final_sp

# %%
# features/target, train/test dataset 분리
X_train, X_test, y_train, y_test = train_test_split(df_final_sp.drop('Cancelled',axis=1), df_final_sp['Cancelled'], test_size=0.3, random_state=111)

# %%
rf_clf1 = RandomForestClassifier(n_estimators = 100, 
                                max_depth = 12,
                                min_samples_leaf = 8,
                                min_samples_split = 8,
                                random_state = 111,
                                n_jobs = -1)
rf_clf1.fit(X_train, y_train)

# %%
# 특정 임계값(0.01804)을 사용하여 이진 분류 예측 수행
threshold = 0.01804
y_pred = (y_pred_prob >= threshold).astype(int)

# 오차 행렬 출력
conf_matrix = confusion_matrix(y_test, y_pred)
print('오차 행렬:\n', conf_matrix)

# ROC 커브 계산
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# ROC 커브 그리기
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### DecisionTree 모델

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

DT=DecisionTreeClassifier(random_state=111,max_depth=30)
DT.fit(X_train,y_train)

pred_DT=DT.predict(X_test)
pp_DT=DT.predict_proba(X_test)[:,1]
get_clf_eval(y_test,pred_DT)

# %%
def roc_curve_plot(y_test, pred_proba_c1):
    fprs, tprs, thresholds = roc_curve(y_test, pred_proba_c1)
    plt.plot(fprs, tprs, label='ROC')
    plt.plot([0,1], [0,1], 'k--', label='Random')
    
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start,end,0.1),2))
    plt.xlim(0,1);plt.ylim(0,1)
    plt.xlabel('FPR(1-Specificity)');plt.ylabel('TPR(Recall)')
    plt.legend()
    
roc_curve_plot(y_test, pp_DT)

# %%
from sklearn.preprocessing import Binarizer

custom_threshold = 0.01804
pp = pp_DT.reshape(-1, 1)

binarizer = Binarizer(threshold=custom_threshold).fit(pp)
custom_predict = binarizer.transform(pp)

print('임계치가 {0}일때,'.format(custom_threshold))
get_clf_eval(y_test, custom_predict)

ra_DT = roc_auc_score(y_test, custom_predict)
print('ROC AUC 값(DecisionTree):{0:.4f}'.format(ra_DT))

# %%
roc_curve_plot(y_test, custom_predict)
